# %%
s = 'ala ma kota'

# %%
s.upper()
# Out:
# 'ALA MA KOTA'

# %%
print(s)
# Out:
# ala ma kota

# %%
s.lower()
# Out:
# 'ala ma kota'

# %%
s.capitalize()
# Out:
# 'Ala ma kota'

# %%
s.title()
# Out:
# 'Ala Ma Kota'

# %%
s += ' i 2 wszy'

# %%
s
# Out:
# 'ala ma kota i 2 wszy'

# %%
# ala ma kota i 2 wszy
# + w tekstach to nie jest operator dodawania , to operator konkatenacji (concatenate)
s[:14] + '2' + s[-5:]
# Out:
# 'ala ma kota i 2 wszy'

# %%
s.replace('i', 'i 2')
# Out:
# 'ala ma kota i 2 2 wszy'

# %%
s.replace('ala', 'roman')
# Out:
# 'roman ma kota i 2 wszy'

# %%
s.startswith('roman')
# Out:
# False

# %%
s.isdigit()
# Out:
# False

# %%
s
# Out:
# 'ala ma kota i 2 wszy'

# %%
s[-6]
# Out:
# '2'

# %%
type(s[-6])
# Out:
# str

# %%
s[-6].isdigit()
# Out:
# True

# %%
float(s[-6])
# Out:
# 2.0

# %%
s.split('kota')
# Out:
# ['ala ma ', ' i 2 wszy']

# %%
l=s.split()
l
# Out:
# ['ala', 'ma', 'kota', 'i', '2', 'wszy']

# %%
l = s.replace('ala', 'roman')
l
# Out:
# 'roman ma kota i 2 wszy'

# %%
l = s.split()

# %%
[word  for word in l]
# Out:
# ['ala', 'ma', 'kota', 'i', '2', 'wszy']

# %% [markdown]
# ### Ternary operator ( operator trójkowy):
# ```python
#
# x = True if condition else False
# x = 10 if 42 < 666 else 'Ala ma kota'
#
# .
# ```

# %%
x = 10 if 42 > 666 else 'Ala ma kota'
x
# Out:
# 'Ala ma kota'

# %%
[int(word) if word.isdigit() else word for word in l]
# Out:
# ['ala', 'ma', 'kota', 'i', 2, 'wszy']

# %%
l[0] = 'ola'

# %%
l
# Out:
# ['ola', 'ma', 'kota', 'i', '2', 'wszy']

# %%
l
# Out:
# ['ola', 'ma', 'kota', 'i', '2', 'wszy']

# %%
str(l)
# Out:
# "['ola', 'ma', 'kota', 'i', '2', 'wszy']"

# %%
# metoda join
s2 = " ".join(word for word in l)
s2
# Out:
# 'ola ma kota i 2 wszy'

# %%
s2 # 'ola ma kota'
# Out:
# 'ola ma kota i 2 wszy'

# %%
s2 = s2[:-8]
s2
# Out:
# 'ola ma kota '
