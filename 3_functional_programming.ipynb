# %% [markdown]
# # Programowanie funkcyjne
#
# 1. Pure Functions
# 2. First-Class Functions
# 3. Higher-Order Functions
# 4. Function Composition
# 5. Anonimous (lambda) Functions
# 6. Closure
# 7. Recursion
# 8. Lazy evaluation
# 9. Immutability
# 10. Decorators
# 11. Generators and Iterators
# 12. Currying and Partial Applications
# 13. Referential Transparency
# 14. Stream and Pipelines
# 15. Monads and Functors

# %% [markdown]
# -------------------------------------------------
#
# #### Pure functions
# - są predyktywne, dla tego samego inputu, dają ten sam output
# - nie może mieć side effects (nie może modyfikować nic poza fn, jak również nic poza funkcją nie może na nią wpływać)
#
# #### Rodzaje side effects
# 1. praca z plikami
# 2. praca z API
# 3. praca z bazą danych (bo API)
#
# -------------------------------------------------

# %% [markdown]
# #### First-Class Functions
#
# - fn są najwyższej poziomu abstrakcją (są obiektami)
#
# -------------------------------------------------
#
# #### Highier-Order Functions
#
# - mogą przyjmować deklaracje innej fn jako parametr lub/i ją zwracać
#
# -------------------------------------------------
#
# #### Anonymous fns ( lambda)
#
# -
#
# -------------------------------------------------

# %% [markdown]
# ### Composition
# - funkcje można komponować ze sobą
# - używane do dziedziczenia
# - wynik jednej fn staje się argumentem kolejnej
# - w zależności, jaką fn przekaże do fn mam róźne zachowania tej fn (np. map / filter / reduce )
#
# ```python
#
# def magic(fn):
#     return fn('ala')
#
# magic(len) # 3
# magic(print) # None
#
# ```
#
# -------------------------------------------------

# %% [markdown]
# #### Closure
#
# Tworzenie closure:
# - minimum 2 funkcje, jedna w drugiej
# - funkcja zewnętrzna (outer) musi zwracać deklaracje funkcji wewnętrznej (inner)
# - funkcja wewnętrzna (inner) musi używać czegoś (identyfikatora) z funkcji zewnętrznej (outer)
#
# Zalety:
# - persystencję (trwałość) - dodaje persystencje do efemerycznego świata wywołań funkcji
#
# Wady:
# - potencjalnie memory-leak
#
# Definicja:
# - dostęp do zmiennych spoza aktualnie wykonywanego zasięgu

# %%
def first_fn():
    x = 42

    def second_fn():
        return f'Odpowiedź na wszystkie pytania: {x}'

    return first_fn

# %% [markdown]
# -------------------------------------------------
#
# #### Recursion
# - wywoływanie samej siebie
#
# -------------------------------------------------
#
# #### Immutability
# - nie modyfikujemy obiektu, tylko tworzymy nowy
#
# Zastosowanie:
# - wydajność. Taniej jest wziąźć nowy, niż modyfikować stary.
# - predyktywność zmian
#
# Niemodyfikowalny stan aplikacji (biblioteka Redux w JS)
# - można osiągnąć podróż w czasie
# - łatwy debug
#
# -------------------------------------------------
#
# #### Decorators
# - Design pattern
# - funkcjonalność python
#     - dekoratory funkcji (konieczne użycie closure)
#     - dekoratory class (sexy alternatywa do metaclass)
#
# Możliwość modyfikacji działania funkcji bez zmiany jej implementacji.
#
# -------------------------------------------------
#
# #### Currying
# - każdą fn wieloparametrową można zamienić na wiele fn jednoparametrowych (unary functions)
#
# -------------------------------------------------
#
# #### Lazy evaluation
#     - generator expression
#     - generators  + stream (dane w czasie) = EDD -> programowanie w oparciu o zdarzenia (event)
#       Reactive Programming - opiera się o zmianę strem'ów -> RxPy
#     - iteratory
#
# - opóźnienie kalkulacji, aż do momentu gdy będą potrzebne
#
# -------------------------------------------------
#
# #### Referential Transparency
#
# - wyrażenie można zastąpić jego wartością bez zmiany zachowania programu.
